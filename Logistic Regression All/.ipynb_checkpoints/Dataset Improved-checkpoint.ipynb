# %%
import re
import nltk
import numpy as np
import sklearn
import pandas as pd
from patsy import dmatrices
from scikitplot import plotters as skplt
import matplotlib.pyplot as plt
from pandas import Series
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
from nltk.stem import RegexpStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn import metrics
from sklearn.metrics import roc_curve, auc, classification_report

'''
# read the entire file into a python array
with open('../../data/tweetDB-AU-15-Oct.json', 'rb') as f:
    data = f.readlines()
# remove the trailing "\n" from each line
#with open('./random_sample.json', 'rb') as f:
#    data = f.readlines()
data = map(lambda x: x.rstrip(), data)
data_json_str = "[" + ','.join(data) + "]"
# now, load it into pandas
sample = pd.read_json(data_json_str)
'''

train3 = pd.read_json("../../data/RelatedVsNotRelated.json")
train2 = pd.read_json("../../data/AwarenessVsInfection.json")
train = pd.read_json("../../data/SelfVsOthers.json")

# ## Awareness Vs Infection
# 0: Influenza infection
# 1: Influenza awareness
train_infection = train2.loc[train2['type'] == 0]
train_awareness = train2.loc[train2['type'] == 1]

# ## Self Vs Others
# 0: Others (the tweet describes someone else)
# 1: Self (the tweet describes the author)
train_others = train.loc[train['type'] == 0]
train_self = train.loc[train['type'] == 1]

# Define Word Stops
stopset = set(stopwords.words('english'))
morewords = ["'s", "swine", "bird", "h1n1", "'ve", "lol", "pig"]
stopset.update(morewords)
#Remove word from stopword list
itemsToRemove = ['can','am', 'are', 're', 'm','have','has','i', 'you', 'he', 'she', 'we', 'they']
stopset = [x for x in stopset if x not in itemsToRemove]

#Methods
# Remove URLs, RTs, and twitter handles
def clean_data(text):
    text= text.decode('utf-8')
    text = text.replace('[^\x00-\x7F]','')
    words = [text for text in text.split() if 'http' not in text and not text.startswith('@') and text != 'RT']
    return ' '.join(words)

# Text to Lower Case
def text_to_lower(text):
    return text.lower()

# Remove some characters
def remove_special_characters(text):
    bad_chars = '-#?(){}<>:;.!$%&/=+*^-`\'0123456789'
    rgx = re.compile('[%s]' % bad_chars)
    return rgx.sub('', text)

# Create a set of Stopwords
def remove_stopwords(text):
    word_tokens = word_tokenize(text)
    filtered_sentence = [w for w in word_tokens if not w in stopset]
    filtered_sentence = []
    for w in word_tokens:
        if w not in stopset:
            filtered_sentence.append(w)

    return ' '.join(filtered_sentence)

# Stemming words
def stem_words(text):
    words = word_tokenize(text)
    #Regex for Suffixes
    st = RegexpStemmer('ing$|s$|able$|ible$|ful$|less$|ive$|acy$|al$|ance$|ence$|dom$|er$|or$|ism$|ist$|ity$|ty$|ment$|ship$|sion$|tion$|ate$|en$|ify$|fy$|ize$|ise$', min=4)
    stemmed = []
    for word in words:
        stemmed.append(st.stem(word))
    return ' '.join(stemmed)


def clean_text(df):
    for i, row in df.iterrows():
      cleaned_text = row['text']
      cleaned_text= clean_data(cleaned_text)
      cleaned_text= text_to_lower(cleaned_text)
      cleaned_text= remove_special_characters(cleaned_text)
      cleaned_text= remove_stopwords(cleaned_text)
      cleaned_text= stem_words(cleaned_text)
      df.set_value(i,'text',cleaned_text)
    return df

def create_wordcloud(list_words, name_cloud):
    wordcloud = WordCloud(
                      stopwords= stopset,
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(list_words)
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.savefig('./wordclouds/'+name_cloud, dpi=300)
    plt.show()

def print_frequency(words, number):
    # Calculate frequency distribution
    fdist = nltk.FreqDist(words)
    for word, frequency in fdist.most_common(number):
        print('{},'.format(word))

# %%
#len(data_df)
'''
sample = sample.sample(n=2000,random_state=1)
data_df= sample[['id_tweet', 'text']]
data_df['type'] = pd.Series(0, index=data_df.index)
data_df= data_df.rename(columns={'id_tweet':'id'})
data_df
out = data_df.to_json(orient='records')
with open('./random_sample.json', 'w') as f:
    f.write(out)
'''
#data_df.to_csv('./random_sample.csv',header ='id, text, RESULT', index=False, encoding='utf-8')
# Out:
# "\nsample = sample.sample(n=2000,random_state=1)\ndata_df= sample[['id_tweet', 'text']]\ndata_df['type'] = pd.Series(0, index=data_df.index)\ndata_df= data_df.rename(columns={'id_tweet':'id'})\ndata_df\nout = data_df.to_json(orient='records')\nwith open('./random_sample.json', 'w') as f:\n    f.write(out)\n"

# %%
random_sample = pd.read_json("./random_sample.json")
random_sample.head()
# Out:
#                                                   id  \
# 0  afebbe96529239db53364ca1423fbe0f3b3d88d97892cb...
# 1  b884772e74bb8ac903e764b676a769761369d3c7f1baea...
# 2  7cfcdc777a9366b9f146c195af51c34eeb9d2c37b2ebaa...
# 3  0474458ceffa52e9fe3d4e50deb8613d0b1e7569eada99...
# 4  5496f87b8033a6b3f4fe54a506bc2d5196fc7aab75de21...
#
#                                                 text  type
# 0  Central Coast Mariners CEO says having Dyldam ...     0
# 1    Willie Nelson's original Crazy was written a...     0
# 2    - The Greens &amp; other lefties guilty as s...     0
# 3   Hello Erin welcome to Adelaide, I am in awe o...     0
# 4  Lake St Clair is beautiful. I would recommend ...     0

# %%
print '(0)train not related(random sample):',len(random_sample)
print '(0)train awareness:', len(train_awareness)
print '(1)train infection:',len(train_infection)
print '(1)train self:',len(train_self)
# Out:
# (0)train not related(random sample): 2000
# (0)train awareness: 1417
# (1)train infection: 1454
# (1)train self: 1482

# %%
# Concat 4 training datasets
# Change Awareness value 1 to 0
print '(0) not related(sample) + awareness:', (len(train_notrelated)+len(train_awareness))
print '(1) infection + self:', (len(train_infection)+len(train_self))

train_awareness.loc[train_awareness.type == 1, 'type'] = 0
frames = [random_sample,train_awareness,train_infection, train_self]
result = pd.concat(frames)
#Drop Duplicate
#result = result.drop_duplicates(subset=['id'], keep=False)
# Unique ID
#len(result.text.unique())
out = result.to_json(orient='records')
with open('./trainall.json', 'w') as f:
    f.write(out)

dataset = pd.read_json('./trainall.json')
dataset
#result.to_csv('train.csv',index=False, sep=',',columns= header,encoding='utf-8')
#train_all= pd.read_csv("./trainall.csv")
#train_all.head()
# Out:
# (0) not related(sample) + awareness: 4071
# (1) infection + self: 2936
#                                                      id  \
# 0     afebbe96529239db53364ca1423fbe0f3b3d88d97892cb...
# 1     b884772e74bb8ac903e764b676a769761369d3c7f1baea...
# 2     7cfcdc777a9366b9f146c195af51c34eeb9d2c37b2ebaa...
# 3     0474458ceffa52e9fe3d4e50deb8613d0b1e7569eada99...
# 4     5496f87b8033a6b3f4fe54a506bc2d5196fc7aab75de21...
# 5     5ac5a0f617f4e4f422d9031a6a560bfe3a80d2d7097a31...
# 6     403d3613dd6608820e9f282e03be3c27d56ed4ba7ece74...
# 7     4994c2ee4f917a8a204e959267632eaf6d590596136f56...
# 8     7e928e18f8309b9f3ba89abaa884c2e2f66672696a6a5e...
# 9     0abfa5588cc3dd0ab3816995644953f45f621b114d3a75...
# 10    49d0980c5fa591534e67a5a4b7e6ac60dbade35b2c8e29...
# 11    79ac66a215e7daca84efbed71b3b52afdfda35ee51ee3d...
# 12    2d2fcce628316e63d142717e7155f68e5d59138ff0bb92...
# 13    cf784e8b153c67d8dc8690b368131e592e4b61fb2e7fcd...
# 14    509f68db19e94f22ed4d4c9baf8694ddfb7caefc638e15...
# 15    ce14852e108fb2b229a113779d9cf6058142a8438495be...
# 16    3d484f4fe74fdbe99286678ee6feb93b41196229f783cf...
# 17    97d85ea887ad563516f8c0667ebfc71421657c25b20b6e...
# 18    fcb1751bff57ce91be6b1af265ff3269dd17c69cba7758...
# 19    6e3d4bed74b21ded9b1992e59f641b7fe3e6511f8ff4f1...
# 20    434ac05a613ae0c8ff22b1fc38983b7ebab0b43a59f0f9...
# 21    ecf770beadbde38d4529eb9ed9a5d9b4ee71029b26552e...
# 22    15adb7d0cc6ffa43c83d6d1ef1ad676cbcbed490f56c44...
# 23    a0688509318141ff42a64ae31b6200138311b21bbc3224...
# 24    a73a6a76724af6d7297c2b88029f0ea25a461c7e46c38e...
# 25    3d6ac14debdba7b3e85f96e0f07176879782c3e22d4086...
# 26    f0d02e4271b4863e0f1eaa59eb31ff691e5e4e227d81fe...
# 27    06b7571e54b8a718cf738e8a630d620c1d7cab7762298f...
# 28    8107dd3a4afefd29b88665362a6a53fde03a79f74f1185...
# 29    01e5ee5e76456e97c102bde30ce919187cd07839cb8f57...
# ...                                                 ...
# 3257                                         3868161801
# 3258                                         3926162604
# 3259                                         4449155706
# 3260                                         4039451609
# 3261                                         4486076802
# 3262                                         4550797702
# 3263                                         4578997405
# 3264                                         4803207404
# 3265                                         4156707013
# 3266                                         3735083213
# 3267                                         4321722609
# 3268                                         3833415308
# 3269                                         4004434114
# 3270                                         4473631701
# 3271                                         4485016013
# 3272                                         4560529708
# 3273                                         4729460205
# 3274                                         4080253109
# 3275                                         4137967001
# 3276                                         4396427411
# 3277                                         4481153707
# 3278                                         4497592805
# 3279                                         4088482908
# 3280                                         4534710500
# 3281                                         4741258205
# 3282                                         4449650206
# 3283                                         4771876902
# 3284                                         5271226206
# 3285                                         5863350206
# 3286                                         5184144107
#
#                                                    text  type
# 0     Central Coast Mariners CEO says having Dyldam ...     0
# 1       Willie Nelson's original Crazy was written a...     0
# 2       - The Greens &amp; other lefties guilty as s...     0
# 3      Hello Erin welcome to Adelaide, I am in awe o...     0
# 4     Lake St Clair is beautiful. I would recommend ...     0
# 5       We certainly need to do something but how fa...     0
# 6     Global deal reached to limit use of hydrofluor...     0
# 7                 finish your homework and go to bed 😆     0
# 8            When you can't afford life so you just cry     0
# 9     "Cool ridings" from Sunday morning, I think th...     0
# 10    Melo Monday because why not? Haha! 😂\nIt's ju...     0
# 11                           Love this song! #xfactorau     0
# 12              so you're telling me there's a chance.      0
# 13        They don't show their true face to the world      0
# 14                             VIOLET CHACHKI DID THAT      0
# 15                                👌😂 I got this 😳💪      0
# 16    "They don't pay you for the sex. They pay you ...     0
# 17    Break fast with a view 😊 #sydney #housesittin...     0
# 18    Discussing tactics for acting assertively in t...     0
# 19                        Oh Barnaby. #auspol #insiders     0
# 20                hey beautiful lady, how was your day?     0
# 21    I'm gobsmacked. \n\n. Please intervene and pas...     0
# 22        I'm actually starting to like you Nick. Ca...     0
# 23                                Thank you! 🙏🏻 🙏🏻      0
# 24     i loved it too!!! i can't believe i forgot ho...     0
# 25      \n\nYes there is a debit side (left) and a c...     0
# 26      I watched the replay at lunchtime. You would...     0
# 27     Hi Karen! I've just revamped the upgrade page...     0
# 28    PRO\nLast night I got to see the amazing and b...     0
# 29    Such a odd day with #cfb results. So many upse...     0
# ...                                                 ...   ...
# 3257  At the doctor getting checked for the flu.. Ma...     0
# 3258  Just threw up in the bathroom. Might be nervou...     0
# 3259   yea i was trying to avoid getting sick again ...     0
# 3260  but i'm well worried about megan she might hav...     0
# 3261                      I think he's getting the flu.     0
# 3262  Loads of ppl are getting sick! Don't want to b...     0
# 3263  Landon has the swine flu and I'm a nervous wre...     0
# 3264  Thinking I may be coming down with the flu not...     0
# 3265  not feeling good today hope i aint getting the...     0
# 3266  Getting very tired and run down now. I hope I ...     0
# 3267  didnt go to school today. i hope im not gettin...     0
# 3268  People getting Swine Flu around me. That's not...     0
# 3269  So.. kid has low-grade fever and muscle cramps...     0
# 3270  Two sick kids... getting checked for swine flu...     0
# 3271  \n-_- Ok that was lame. LOL I'm not getting yo...     0
# 3272     and i think im getting the flu my brother had.     0
# 3273  No school run today both siblings are out for ...     0
# 3274  might be getting sick. if it's swine flu I'm s...     0
# 3275  Is going to bed soon...if I get worse I'm gett...     0
# 3276                   --hope u arent getting swine flu     0
# 3277  Back from the match and trying to hide from th...     0
# 3278  what great timing...matt woke up this morning ...     0
# 3279  LC has stomach flu. Dehydrated!!!! He has neve...     0
# 3280  Fingers crossed that I'm not getting the flu b...     0
# 3281  I just hate being sick havent had the flu n 9 ...     0
# 3282    Thinking of you and Graeme (and Erik). Sleep...     0
# 3283  hope im not getting the flu!; lost my riiing :...     0
# 3284  gonna get my swine and flu shot today.. yay :|...     1
# 3285  is getting the swine flu jab on Tuesday. Want ...     1
# 3286                       getting a pig flu shot soon!     1
#
# [3287 rows x 3 columns]

# %%
pd.value_counts(dataset['type'].values, sort=False)
# Out:
# 0    3284
# 1       3
# dtype: int64

# %%
dataset.loc[dataset['type'] == 4786269900]
# Out:
# Empty DataFrame
# Columns: [id, text, type]
# Index: []

# %%
dataset
# Out:
#                                                      id  \
# 0     afebbe96529239db53364ca1423fbe0f3b3d88d97892cb...
# 1     b884772e74bb8ac903e764b676a769761369d3c7f1baea...
# 2     7cfcdc777a9366b9f146c195af51c34eeb9d2c37b2ebaa...
# 3     0474458ceffa52e9fe3d4e50deb8613d0b1e7569eada99...
# 4     5496f87b8033a6b3f4fe54a506bc2d5196fc7aab75de21...
# 5     5ac5a0f617f4e4f422d9031a6a560bfe3a80d2d7097a31...
# 6     403d3613dd6608820e9f282e03be3c27d56ed4ba7ece74...
# 7     4994c2ee4f917a8a204e959267632eaf6d590596136f56...
# 8     7e928e18f8309b9f3ba89abaa884c2e2f66672696a6a5e...
# 9     0abfa5588cc3dd0ab3816995644953f45f621b114d3a75...
# 10    49d0980c5fa591534e67a5a4b7e6ac60dbade35b2c8e29...
# 11    79ac66a215e7daca84efbed71b3b52afdfda35ee51ee3d...
# 12    2d2fcce628316e63d142717e7155f68e5d59138ff0bb92...
# 13    cf784e8b153c67d8dc8690b368131e592e4b61fb2e7fcd...
# 14    509f68db19e94f22ed4d4c9baf8694ddfb7caefc638e15...
# 15    ce14852e108fb2b229a113779d9cf6058142a8438495be...
# 16    3d484f4fe74fdbe99286678ee6feb93b41196229f783cf...
# 17    97d85ea887ad563516f8c0667ebfc71421657c25b20b6e...
# 18    fcb1751bff57ce91be6b1af265ff3269dd17c69cba7758...
# 19    6e3d4bed74b21ded9b1992e59f641b7fe3e6511f8ff4f1...
# 20    434ac05a613ae0c8ff22b1fc38983b7ebab0b43a59f0f9...
# 21    ecf770beadbde38d4529eb9ed9a5d9b4ee71029b26552e...
# 22    15adb7d0cc6ffa43c83d6d1ef1ad676cbcbed490f56c44...
# 23    a0688509318141ff42a64ae31b6200138311b21bbc3224...
# 24    a73a6a76724af6d7297c2b88029f0ea25a461c7e46c38e...
# 25    3d6ac14debdba7b3e85f96e0f07176879782c3e22d4086...
# 26    f0d02e4271b4863e0f1eaa59eb31ff691e5e4e227d81fe...
# 27    06b7571e54b8a718cf738e8a630d620c1d7cab7762298f...
# 28    8107dd3a4afefd29b88665362a6a53fde03a79f74f1185...
# 29    01e5ee5e76456e97c102bde30ce919187cd07839cb8f57...
# ...                                                 ...
# 1970  bf760b238a61e28ec37847dde1f729bae27c2fe0d15d19...
# 1971  955640b03314cd4ca2dd8d007f6a6657d201ac9cfdee2b...
# 1972  41e1ebe36834d17dbf9cce34a2286f654c80f8a081047a...
# 1973  78e37bd2e46640684c1ceae154ba8fb2c8dd0916d356eb...
# 1974  1b83f82a6916a04a1b32c9bb242af24239bc64eda463c0...
# 1975  d5ccbb2e553935eac1258767188f22d8c460b1db7f0234...
# 1976  ce2b7a0bd1022604d740af8297725b7d66c814572e8ed9...
# 1977  60051cdbea45b00e9f38800355b6186fd278dd8075f7f3...
# 1978  0ef8473563dd75e97d98e9d1b9df1949f2b3c13c594d7e...
# 1979  0dcb259b31eb9b140389a6e98ebdc71aefa8af154be685...
# 1980  b4eeba7f30797417d77c475c1511dce96dda21170d68d6...
# 1981  ed6f1035675298e30c19240e63991ac79854e080d4e4cd...
# 1982  c47c0140a7b22e9e1970a89dbd9bb79cb77440bdc4f38b...
# 1983  ce02ab6e905e191cd9613b42e19fd5bd64037d5014d52f...
# 1984  ce9dda2b171aedec3abfab193716a92ad211821ce2b4bf...
# 1985  fd2a5aa355d12dc11be44a3d634ea6a86158f75a16a61c...
# 1986  df1992449b31a518a677d483fd2f9d25e725649cbf37a2...
# 1987  ecc08f433b80a2f2306639364066184fa646a69a1c3fa1...
# 1988  ea8bc5a7761e3d6e853d91089a51b81c507213e855add7...
# 1989  0128033b95ed8008adc58b49032e133013d3ae1ba6cbd3...
# 1990  f5f9312e474d2e65f885970e576529bf384121d76604a4...
# 1991  d1c0a16d9e3842b6e0cf6c7a1f256532a3b22ae30df61f...
# 1992  fcf5a52e819741b93765221e7b0246231af74df4753a61...
# 1993  3ae570229f24e18e6b804101c0c018e6160eb04ae3ce28...
# 1994  e249c05bd3d4fb4f5dfae45f38fd4e7237bd97d0a43764...
# 1995  760c67df32a5c7e6c1e77ec1c9292140423d649be1643e...
# 1996  bce45dc91abbed958ff217280f8d5bacda9b850228cf48...
# 1997  73da638b2cfe031170df9d3c486502f7be3082ca053fbf...
# 1998  e13f6cfcdde61e227cb607c0c4fc5f43db9b4e0f3b672a...
# 1999  b0cc804cce0c6b6b29f484e1ef5fbdbbca23b4d1113e32...
#
#                                                    text  type
# 0     Central Coast Mariners CEO says having Dyldam ...     0
# 1       Willie Nelson's original Crazy was written a...     0
# 2       - The Greens &amp; other lefties guilty as s...     0
# 3      Hello Erin welcome to Adelaide, I am in awe o...     0
# 4     Lake St Clair is beautiful. I would recommend ...     0
# 5       We certainly need to do something but how fa...     0
# 6     Global deal reached to limit use of hydrofluor...     0
# 7                 finish your homework and go to bed 😆     0
# 8            When you can't afford life so you just cry     0
# 9     "Cool ridings" from Sunday morning, I think th...     0
# 10    Melo Monday because why not? Haha! 😂\nIt's ju...     0
# 11                           Love this song! #xfactorau     0
# 12              so you're telling me there's a chance.      0
# 13        They don't show their true face to the world      0
# 14                             VIOLET CHACHKI DID THAT      0
# 15                                👌😂 I got this 😳💪      0
# 16    "They don't pay you for the sex. They pay you ...     0
# 17    Break fast with a view 😊 #sydney #housesittin...     0
# 18    Discussing tactics for acting assertively in t...     0
# 19                        Oh Barnaby. #auspol #insiders     0
# 20                hey beautiful lady, how was your day?     0
# 21    I'm gobsmacked. \n\n. Please intervene and pas...     0
# 22        I'm actually starting to like you Nick. Ca...     0
# 23                                Thank you! 🙏🏻 🙏🏻      0
# 24     i loved it too!!! i can't believe i forgot ho...     0
# 25      \n\nYes there is a debit side (left) and a c...     0
# 26      I watched the replay at lunchtime. You would...     0
# 27     Hi Karen! I've just revamped the upgrade page...     0
# 28    PRO\nLast night I got to see the amazing and b...     0
# 29    Such a odd day with #cfb results. So many upse...     0
# ...                                                 ...   ...
# 1970  Waiting for a catch! #river #fishcatching #for...     0
# 1971                     Omg I've corrupted you 😂😂😂      0
# 1972  💪🏻🍆Season 4 Ep 2! What a top crowd! The Con...     0
# 1973  Believe that's unfair   50-70s alienated audie...     0
# 1974  Which version of the Four Tops' song do u like...     0
# 1975   yeah I feel that as well on my 'work from hom...     0
# 1976    thankfully I missed tonight, as that topic m...     0
# 1977  🇦🇺 Loss to all Victorian. Est. 1850s when:\n...     0
# 1978                       u look like Marilyn Monroe😍     0
# 1979                                    yay tax bill!!!     0
# 1980           You're doing the right thing Sam. Bravo.     0
# 1981    Is narrative - especially dramatic narrative...     0
# 1982  Sam has a video of me passed out in so random ...     0
# 1983              Dude your voice is INSANE! #xfactorau     0
# 1984  At Linda Emery &amp; Associates we are experie...     0
# 1985  Someone actually said "watch them tease a game...     0
# 1986  Such a #Gorgeous #Wedding I was able to attend...     0
# 1987  When technology is engineered with purpose it ...     0
# 1988                       lol cracked me up that tweet     0
# 1989    OMG, how brilliant &amp; shattering is this ...     0
# 1990  Who called it adding insult to the injury of l...     0
# 1991  The goals are really flowing so far in 9 games...     0
# 1992   yeah - these types of deals shaft Aus badly. ...     0
# 1993        looks like they had a good time sort of lol     0
# 1994                                     your total 😏      0
# 1995           She's a red too! #GoStags #AGordonForMe      0
# 1996  ,,,someone on fb just shared a video of someon...     0
# 1997    Imagine you were arrested without charge and...     0
# 1998     I don't understand why LGBTI relationships ...     0
# 1999  Fun second day with more great conquering canc...     0
#
# [2000 rows x 3 columns]
